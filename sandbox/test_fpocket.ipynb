# %%
import molsysmt as msm
import topomt as tmt
# Out:
# MOLSYSMT WARNING | UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.

# %%
pdbfile = tmt.demo['FPocket2']['3LKF.pdb']

# %%
pockets = tmt.methods.fpocket2(molecular_system=pdbfile)
# Out:
# POCKETMT WARNING | UserWarning: Removing 264 atoms from fpocket analysis (waters=253, ions=0, small_molecules=1).

# %%
for ii in pockets:
    print(len(ii))
# Out:
# 83
# 82
# 104
# 68
# 50

# %%
result = tmt.wrappers.fpocket.parse_fpocket_output(pdbfile, tmt.demo['FPocket2']['3LKF_out'])

# %%
len(result.to_dict())
# Out:
# 4

# %%
#out_dir = tmt.wrappers.fpocket.run_fpocket(pdbfile)

# %%
#result = tmt.wrappers.fpocket.parse_fpocket_output(pdbfile, out_dir)

# %%
#len(result.to_dict())
