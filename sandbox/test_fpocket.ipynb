# %%
import molsysmt as msm
import topomt as tmt
# Out:
# MOLSYSMT WARNING | UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.

# %%
molsys = msm.convert(tmt.demo['TcTIM']['1tcd.pdb'], to_form='molsysmt.MolSys')

# %%
molsys = msm.extract(molsys, selection='molecule_type not in ["water", "ion", "small molecule"]')

# %%
#msm.info(molsys)

# %%
alpha_spheres = tmt.methods.fpocket(molecular_system=molsys)
# Out:
# POCKETMT WARNING | NotDigestedArgumentWarning: The min_alpha_sphere_radius from topomt.methods.fpocket.fpocket argument was not digested.Check  for more information. If you still need help, open a new issue in https://github.com/uibcdf/topomt/issues.
#
# POCKETMT WARNING | NotDigestedArgumentWarning: The max_alpha_sphere_radius from topomt.methods.fpocket.fpocket argument was not digested.Check  for more information. If you still need help, open a new issue in https://github.com/uibcdf/topomt/issues.
#
# POCKETMT WARNING | NotDigestedArgumentWarning: The radii from topomt.alpha_spheres.alpha_spheres.__init__ argument was not digested.Check  for more information. If you still need help, open a new issue in https://github.com/uibcdf/topomt/issues.
#
# POCKETMT WARNING | NotDigestedArgumentWarning: The skip_digestion from topomt.alpha_spheres.alpha_spheres.__init__ argument was not digested.Check  for more information. If you still need help, open a new issue in https://github.com/uibcdf/topomt/issues.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 alpha_spheres = tmt.methods.fpocket(molecular_system=molsys)
#
# File ~/repos@uibcdf/molsysmt/molsysmt/_private/digestion/digest.py:122, in digest.<locals>.digestor.<locals>.wrapper(*args, **kwargs)
#     120     return func(all_args['self'], **final_args)
#     121 else:
# --> 122     return func(**final_args)
#
# File ~/repos@uibcdf/topomt/topomt/methods/fpocket.py:42, in fpocket(molecular_system, selection, structure_indices, min_alpha_sphere_radius, max_alpha_sphere_radius, syntax)
#      38 #radii = molsys.get_radii(selection=selection)
#      40 alpha_spheres = AlphaSpheres(points=coordinates[0], radii=None)
# ---> 42 alpha_spheres.remove_small_alpha_spheres(min_alpha_sphere_radius)
#      43 alpha_spheres.remove_big_alpha_spheres(max_alpha_sphere_radius)
#      47 return alpha_spheres
#
# File ~/repos@uibcdf/topomt/topomt/alpha_spheres/alpha_spheres.py:131, in AlphaSpheres.remove_small_alpha_spheres(self, minimum_radius)
#     129 def remove_small_alpha_spheres(self, minimum_radius):
# --> 131     indices_to_remove = np.where(self.radii < minimum_radius)
#     132     self.remove_alpha_spheres(indices_to_remove)
#
# File ~/Myopt/miniconda3/envs/topomt@uibcdf_3.12/lib/python3.12/site-packages/pint/facets/plain/quantity.py:1427, in PlainQuantity.<lambda>(self, other)
#    1422         raise DimensionalityError(
#    1423             self._units, other._units, self.dimensionality, other.dimensionality
#    1424         )
#    1425     return op(self.to_root_units().magnitude, other.to_root_units().magnitude)
# -> 1427 __lt__ = lambda self, other: self.compare(other, op=operator.lt)
#    1428 __le__ = lambda self, other: self.compare(other, op=operator.le)
#    1429 __ge__ = lambda self, other: self.compare(other, op=operator.ge)
#
# File ~/Myopt/miniconda3/envs/topomt@uibcdf_3.12/lib/python3.12/site-packages/pint/facets/plain/quantity.py:101, in check_implemented.<locals>.wrapped(self, *args, **kwargs)
#      99 elif isinstance(other, list) and other and isinstance(other[0], type(self)):
#     100     return NotImplemented
# --> 101 return f(self, *args, **kwargs)
#
# File ~/Myopt/miniconda3/envs/topomt@uibcdf_3.12/lib/python3.12/site-packages/pint/facets/plain/quantity.py:1410, in PlainQuantity.compare(self, other, op)
#    1408                 raise OffsetUnitCalculusError(self._units)
#    1409     else:
# -> 1410         raise ValueError(f"Cannot compare PlainQuantity and {type(other)}")
#    1412 # Registry equality check based on util.SharedRegistryObject
#    1413 if self._REGISTRY is not other._REGISTRY:
#
# ValueError: Cannot compare PlainQuantity and <class 'str'>

# %%
alpha_spheres.get_points_of_alpha_spheres([4])
